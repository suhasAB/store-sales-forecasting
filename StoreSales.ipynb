# %% [markdown]
# ## Data Preprocessing
#
# See commentaries at the end. The dataset was downloaded from [1].
#
# [1] Store Sales -- Time Series Forecasting, an ongoing Kaggle competition.
# Data set available on-line and retrieved on 2022-11-01 at
# https://www.kaggle.com/competitions/store-sales-time-series-forecasting/data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
stores = pd.read_csv("data/stores.csv.gz")
stores.info()
stores.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   store_nbr  54 non-null     int64
#  1   city       54 non-null     object
#  2   state      54 non-null     object
#  3   type       54 non-null     object
#  4   cluster    54 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.2+ KB
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
stores['city'].value_counts()
# Out:
# Quito            18
# Guayaquil         8
# Cuenca            3
# Santo Domingo     3
# Manta             2
# Latacunga         2
# Machala           2
# Ambato            2
# Quevedo           1
# Esmeraldas        1
# Loja              1
# Libertad          1
# Playas            1
# Daule             1
# Babahoyo          1
# Salinas           1
# Puyo              1
# Guaranda          1
# Ibarra            1
# Riobamba          1
# Cayambe           1
# El Carmen         1
# Name: city, dtype: int64

# %%
stores['state'].value_counts()
# Out:
# Pichincha                         19
# Guayas                            11
# Santo Domingo de los Tsachilas     3
# Azuay                              3
# Manabi                             3
# Cotopaxi                           2
# Tungurahua                         2
# Los Rios                           2
# El Oro                             2
# Chimborazo                         1
# Imbabura                           1
# Bolivar                            1
# Pastaza                            1
# Santa Elena                        1
# Loja                               1
# Esmeraldas                         1
# Name: state, dtype: int64

# %%
stores['type'].value_counts()
# Out:
# D    18
# C    15
# A     9
# B     8
# E     4
# Name: type, dtype: int64

# %%
stores['cluster'].value_counts()
# Out:
# 3     7
# 6     6
# 10    6
# 15    5
# 13    4
# 14    4
# 11    3
# 4     3
# 8     3
# 1     3
# 9     2
# 7     2
# 2     2
# 12    1
# 5     1
# 16    1
# 17    1
# Name: cluster, dtype: int64

# %%
oil = pd.read_csv("data/oil.csv.gz")
oil.info()
oil.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1218 non-null   object
#  1   dcoilwtico  1175 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 19.2+ KB
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
oil = oil.dropna()  # certain dates have NaN dcoilwtico

# %%
holidays = pd.read_csv("data/holidays_events.csv.gz")
holidays.info()
holidays.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         350 non-null    object
#  1   type         350 non-null    object
#  2   locale       350 non-null    object
#  3   locale_name  350 non-null    object
#  4   description  350 non-null    object
#  5   transferred  350 non-null    bool
# dtypes: bool(1), object(5)
# memory usage: 14.1+ KB
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
transactions = pd.read_csv("data/transactions.csv.gz")
transactions.info()
transactions.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83488 entries, 0 to 83487
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          83488 non-null  object
#  1   store_nbr     83488 non-null  int64
#  2   transactions  83488 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 1.9+ MB
#          date  store_nbr  transactions
# 0  2013-01-01         25           770
# 1  2013-01-02          1          2111
# 2  2013-01-02          2          2358
# 3  2013-01-02          3          3487
# 4  2013-01-02          4          1922

# %%
sample_submission = pd.read_csv("data/sample_submission.csv.gz")
sample_submission.info()
sample_submission.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      28512 non-null  int64
#  1   sales   28512 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 445.6 KB
#         id  sales
# 0  3000888    0.0
# 1  3000889    0.0
# 2  3000890    0.0
# 3  3000891    0.0
# 4  3000892    0.0

# %%
train = pd.read_csv("data/train.csv.gz")
train.info()
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %% [markdown]
# We can reduce the memory use by changing the Dtypes of the data.

# %%
train['id']=train.id.astype('int32')
train['store_nbr']=train.store_nbr.astype('int32')
train['family']=train.family.astype('category')
train['sales']=train.sales.astype('float32')
train['onpromotion']=train.onpromotion.astype('int32')

# %%
train['family'].value_counts()
# Out:
# AUTOMOTIVE                    90936
# HOME APPLIANCES               90936
# SCHOOL AND OFFICE SUPPLIES    90936
# PRODUCE                       90936
# PREPARED FOODS                90936
# POULTRY                       90936
# PLAYERS AND ELECTRONICS       90936
# PET SUPPLIES                  90936
# PERSONAL CARE                 90936
# MEATS                         90936
# MAGAZINES                     90936
# LIQUOR,WINE,BEER              90936
# LINGERIE                      90936
# LAWN AND GARDEN               90936
# LADIESWEAR                    90936
# HOME CARE                     90936
# HOME AND KITCHEN II           90936
# BABY CARE                     90936
# HOME AND KITCHEN I            90936
# HARDWARE                      90936
# GROCERY II                    90936
# GROCERY I                     90936
# FROZEN FOODS                  90936
# EGGS                          90936
# DELI                          90936
# DAIRY                         90936
# CLEANING                      90936
# CELEBRATION                   90936
# BREAD/BAKERY                  90936
# BOOKS                         90936
# BEVERAGES                     90936
# BEAUTY                        90936
# SEAFOOD                       90936
# Name: family, dtype: int64

# %%
train['sales'].value_counts()
# Out:
# 0.000000       939130
# 1.000000       115291
# 2.000000        85959
# 3.000000        68575
# 4.000000        57846
#                 ...
# 116.541000          1
# 363.532990          1
# 141.322006          1
# 409.878998          1
# 2419.729004         1
# Name: sales, Length: 379610, dtype: int64

# %%
train['onpromotion'].value_counts()
# Out:
# 0      2389559
# 1       174551
# 2        79386
# 3        45862
# 4        31659
#         ...
# 313          1
# 452          1
# 642          1
# 305          1
# 425          1
# Name: onpromotion, Length: 362, dtype: int64

# %%
test = pd.read_csv("data/test.csv.gz")
test.info()
test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28512 entries, 0 to 28511
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           28512 non-null  int64
#  1   date         28512 non-null  object
#  2   store_nbr    28512 non-null  int64
#  3   family       28512 non-null  object
#  4   onpromotion  28512 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
train.tail()
# Out:
#               id        date  store_nbr                      family  \
# 3000883  3000883  2017-08-15          9                     POULTRY
# 3000884  3000884  2017-08-15          9              PREPARED FOODS
# 3000885  3000885  2017-08-15          9                     PRODUCE
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES
# 3000887  3000887  2017-08-15          9                     SEAFOOD
#
#                sales  onpromotion
# 3000883   438.132996            0
# 3000884   154.552994            1
# 3000885  2419.729004          148
# 3000886   121.000000            8
# 3000887    16.000000            0

# %% [markdown]
# ## Dataset Descriptions
#
# There are 7 csv files in the dataset:
#
# + store.csv -- store information (store_nbr --> city, state, type, clusterID)
# + oil.csv -- oil price (date --> price); there are some dates with NaN which are removed
# + holidays_events.csv -- date --> locale, and description of the holiday
# + transaction.csv -- date --> store_nbr, #transactions
# + sample_submission.csv -- described the submission format
# + train.csv (training set) -- id --> date, store_nbr, family, onpromotion
# + test.csv (test set) -- id --> date, store_nbr, family, onpromotion
#
# | File       | #rows     | #rows (cleaned) |
# | ---------- | --------- | ---- |
# | store.csv  | 54        |
# | oil.csv    | 1218 | 1175 |
# | holidays_events.csv  | 350        |
# | transactions.csv  | 83488        |
# | sample_submission.csv  | 28512        |
# | train.csv  | 3000888        |
# | test.csv  | 28512        |

# %% [markdown]
# There are 30000888 rows in the training set, and there are 33 unique "family" values, each appear exactly 90936 times. Note that 90936 times 33 equals 3000888 exactly. Moreover, 90936 equals 54 times 1684, and there are exactly 1684
# unique dates in the training set.
#
# Overall, we have a complete full matrix made of 54 (stores) x 1684 (dates) x 33 (project family) = 3000888 data points.
#
# The dates on the training data range from 2013-01-01 to 2017-08-15 inclusive. There are a total of 1688 days. Note the discrepancy between 1688 and 1684.
#
# For the test data, there are 28512 entries, where 28512 = 54 * 33 * 16. In other words, we are to predict the store sale for the next 16 days, from 2017-08-16 to 2017-03-31 inclusive. Note that this is exactly the dates after the training data.
#
# transaction.csv provides the number of transaction on a per-store, per-day basis. Note that 83488 / 54 = 1546.07. Theoretically it should be 54 * 1684 = 90936 entries, but we only have 83488 entries. The reason is that not all stores have transaction every day. For example, on 2013-01-01, store 25 has 770 transactions and all other stores have zero transactions. The zero transactions are not recorded in transaction.csv
#
# Note that transaction is different from sales. Transaction is not explained. Maybe just the number of transactions, vs sales is a dollar amount.
#
# Also note the commentaries about national holidays, earthquake, etc.
#
# Okay, earlier I misunderstood the meaning of test.csv. We can actually read it. It contains information
# about promotion, etc, but without the sales. We are to predict the sales.

# %%
(pd.to_datetime('2017-08-16') - pd.to_datetime('2013-01-01'))
# Out:
# Timedelta('1688 days 00:00:00')

# %%
train[(train['store_nbr'] == 25) & (train['date'] == '2013-01-01') & (train['sales'] > 0)]
# Out:
#       id        date  store_nbr            family       sales  onpromotion
# 563  563  2013-01-01         25            BEAUTY    2.000000            0
# 564  564  2013-01-01         25         BEVERAGES  810.000000            0
# 566  566  2013-01-01         25      BREAD/BAKERY  180.589005            0
# 568  568  2013-01-01         25          CLEANING  186.000000            0
# 569  569  2013-01-01         25             DAIRY  143.000000            0
# 570  570  2013-01-01         25              DELI   71.089996            0
# 571  571  2013-01-01         25              EGGS   46.000000            0
# 572  572  2013-01-01         25      FROZEN FOODS   29.654999            0
# 573  573  2013-01-01         25         GROCERY I  700.000000            0
# 574  574  2013-01-01         25        GROCERY II   15.000000            0
# 581  581  2013-01-01         25   LAWN AND GARDEN    2.000000            0
# 582  582  2013-01-01         25          LINGERIE    5.000000            0
# 583  583  2013-01-01         25  LIQUOR,WINE,BEER  105.000000            0
# 585  585  2013-01-01         25             MEATS  110.801003            0
# 586  586  2013-01-01         25     PERSONAL CARE   25.000000            0
# 589  589  2013-01-01         25           POULTRY   42.637001            0
# 590  590  2013-01-01         25    PREPARED FOODS   37.847000            0

# %%
train[(train['store_nbr'] == 25) & (train['date'] == '2013-01-01') & (train['sales'] > 0)]['sales'].sum()
# Out:
# 2511.619

# %% [markdown]
# ## Exploratory Data Analysis -- Oil Prices
#
# We first look at the oil prices:

# %%
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
oil.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exploratory Data Analysis -- Aggregate Sales
#
# Here's what the aggregate sales over time look like.

# %%
agg = train.groupby(['date']).sum()
agg = agg.drop(columns=['id', 'store_nbr', 'onpromotion'])
agg.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# We'll also look at a few product categories. The patterns are quite interesting. 's what beverages look like:

# %%
agg = train[train['family'] == 'BEVERAGES'].groupby(['date']).sum()
agg = agg.drop(columns=['id', 'store_nbr', 'onpromotion'])
agg.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
agg = train[train['family'] == 'CLEANING'].groupby(['date']).sum()
agg = agg.drop(columns=['id', 'store_nbr', 'onpromotion'])
agg.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
agg = train[train['family'] == 'SCHOOL AND OFFICE SUPPLIES'].groupby(['date']).sum()
agg = agg.drop(columns=['id', 'store_nbr', 'onpromotion'])
agg.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
agg = train[train['family'] == 'PRODUCE'].groupby(['date']).sum()
agg = agg.drop(columns=['id', 'store_nbr', 'onpromotion'])
agg.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
agg = train[train['family'] == 'HOME CARE'].groupby(['date']).sum()
agg = agg.drop(columns=['id', 'store_nbr', 'onpromotion'])
agg.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## Exploratory Data Analysis -- Aggregate Sales Detailed

# %% [markdown]
# Here are all the categories. we are going to plot all the sale numbers to dates by category.

# %%
category_list = train['family'].value_counts().to_dict().keys()
category_list
# Out:
# dict_keys(['AUTOMOTIVE', 'HOME APPLIANCES', 'SCHOOL AND OFFICE SUPPLIES', 'PRODUCE', 'PREPARED FOODS', 'POULTRY', 'PLAYERS AND ELECTRONICS', 'PET SUPPLIES', 'PERSONAL CARE', 'MEATS', 'MAGAZINES', 'LIQUOR,WINE,BEER', 'LINGERIE', 'LAWN AND GARDEN', 'LADIESWEAR', 'HOME CARE', 'HOME AND KITCHEN II', 'BABY CARE', 'HOME AND KITCHEN I', 'HARDWARE', 'GROCERY II', 'GROCERY I', 'FROZEN FOODS', 'EGGS', 'DELI', 'DAIRY', 'CLEANING', 'CELEBRATION', 'BREAD/BAKERY', 'BOOKS', 'BEVERAGES', 'BEAUTY', 'SEAFOOD'])

# %%
train.groupby('family')['sales'].mean().sort_values(ascending=False).to_frame().plot.bar()
# Out:
# <AxesSubplot:xlabel='family'>

# %%
for category in category_list:
    agg = train[train['family'] == category].loc[:,['sales','date']].groupby(['date']).sum()
    agg.plot(title=category+' sales')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:345: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# Findings:
#
# There are missing data in this dataset. There are 2 sets of categories/families.
#
# 1. Have ddata missing partially or completely before mid 2015.
#
#     ['SCHOOL AND OFFICE SUPPLIES', 'PRODUCE', 'PLAYERS AND ELECTRONICS', 'PET SUPPLIES', 'MAGAZINES', 'LADIESWEAR', 'HOME CARE', 'HOME AND KITCHEN II', 'BABY CARE', 'HOME AND KITCHEN I', 'CELEBRATION', 'BEVERAGES']
#
# 2. Have compelte data from 2013 - 2017
#     ['AUTOMOTIVE', 'HOME APPLIANCES', 'PREPARED FOODS', 'POULTRY', 'PERSONAL CARE', 'MEATS', 'LIQUOR,WINE,BEER', 'LINGERIE', 'LAWN AND GARDEN', 'HOME CARE', 'HARDWARE', 'GROCERY II', 'GROCERY I', 'FROZEN FOODS', 'EGGS', 'DELI', 'DAIRY', 'CLEANING', 'BREAD/BAKERY', 'BEAUTY', 'SEAFOOD']
#
# There is one outliner which is the 'BOOKS' family where there is only data from late 2016 - 2017.

# %% [markdown]
# Thoughts:
#
# 1. Can we just ignore the pre 2015 dates data. We can just use the data after mid 2015 to build our models.
#
# 2. Can we fill in the missing data? It is going to challenging since those are big gaps in the timeline. We might needd to copy the data from the same month and day from 2016/2016 to fill in the missing data.

# %% [markdown]
# Just from these data we detected interesting or problematic patterns by product family. Note also the anomaly that seemingly happens at a regular interval. It turns out there is no data on the first day of each year.

# %% [markdown]
# ## Exploratory Data Analysis -- Correlations
#
# In the following we look at the correlations between different product families.

# %%
homecare = train[train['family'] == 'HOME CARE'].groupby(['date']).sum()
homecare = homecare.drop(columns=['id', 'store_nbr', 'onpromotion'])
cleaning = train[train['family'] == 'CLEANING'].groupby(['date']).sum()
cleaning = cleaning.drop(columns=['id', 'store_nbr', 'onpromotion'])
produce = train[train['family'] == 'PRODUCE'].groupby(['date']).sum()
produce = produce.drop(columns=['id', 'store_nbr', 'onpromotion'])
school = train[train['family'] == 'SCHOOL AND OFFICE SUPPLIES'].groupby(['date']).sum()
school = school.drop(columns=['id', 'store_nbr', 'onpromotion'])

# %%
homecare.rolling(10).corr(cleaning).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
homecare.rolling(10).corr(produce).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
homecare.rolling(10).corr(school).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# We can pivot the table and look at the correlations between all the families.

# %%
pivoted_table = train.pivot_table('sales', ['date'], 'family')
pivoted_table
# Out:
# family      AUTOMOTIVE  BABY CARE    BEAUTY    BEVERAGES     BOOKS  \
# date
# 2013-01-01    0.000000   0.000000  0.037037    15.000000  0.000000
# 2013-01-02    4.722222   0.000000  3.833333  1335.036987  0.000000
# 2013-01-03    2.981482   0.000000  2.314815   964.907410  0.000000
# 2013-01-04    3.129630   0.000000  2.462963  1003.092590  0.000000
# 2013-01-05    6.333333   0.000000  3.537037  1441.074097  0.000000
# ...                ...        ...       ...          ...       ...
# 2017-08-11    8.166667   0.129630  6.500000  3502.055664  0.000000
# 2017-08-12    7.462963   0.055556  6.833333  3376.259277  0.000000
# 2017-08-13    8.907408   0.166667  8.018518  3747.296387  0.018519
# 2017-08-14    5.407407   0.166667  6.240741  3237.629639  0.000000
# 2017-08-15    6.240741   0.148148  6.277778  3162.462891  0.000000
#
# family      BREAD/BAKERY  CELEBRATION     CLEANING       DAIRY        DELI  \
# date
# 2013-01-01      3.344241     0.000000     3.444444    2.648148    1.316481
# 2013-01-02    486.042938     0.000000  1382.018555  432.981476  291.750000
# 2013-01-03    341.786682     0.000000  1035.055542  333.351837  206.897308
# 2013-01-04    309.666077     0.000000   964.148132  336.074066  187.837204
# 2013-01-05    414.217804     0.000000  1298.666626  427.444458  254.350830
# ...                  ...          ...          ...         ...         ...
# 2017-08-11    522.305298    16.111111  1031.148193  831.648132  345.934967
# 2017-08-12    507.473114    15.722222  1072.870361  793.592590  290.553589
# 2017-08-13    615.976990    10.074074  1143.648193  928.000000  325.801361
# 2017-08-14    518.564026    11.000000  1019.111084  797.222229  271.532227
# 2017-08-15    539.966553    11.055555  1082.851807  753.833313  276.582458
#
# family      ...  MAGAZINES       MEATS  PERSONAL CARE  PET SUPPLIES  \
# date        ...
# 2013-01-01  ...   0.000000    2.051870       0.462963      0.000000
# 2013-01-02  ...   0.000000  386.508606     318.592590      0.000000
# 2013-01-03  ...   0.000000  307.359222     232.740738      0.000000
# 2013-01-04  ...   0.000000  400.480804     209.314819      0.000000
# 2013-01-05  ...   0.000000  386.649841     311.462952      0.000000
# ...         ...        ...         ...            ...           ...
# 2017-08-11  ...   9.259259  498.964661     295.888885     10.870370
# 2017-08-12  ...   8.944445  329.178711     294.500000      9.407408
# 2017-08-13  ...   8.685185  345.055817     336.814819     10.018518
# 2017-08-14  ...   8.462963  314.364563     279.203705      7.722222
# 2017-08-15  ...   8.537037  332.003174     273.833344      6.740741
#
# family      PLAYERS AND ELECTRONICS     POULTRY  PREPARED FOODS      PRODUCE  \
# date
# 2013-01-01                 0.000000    0.789574        0.700870     0.000000
# 2013-01-02                 0.000000  258.812683       98.853928     0.000000
# 2013-01-03                 0.000000  197.673965       66.507187     0.000000
# 2013-01-04                 0.000000  199.491013       82.832703     0.000000
# 2013-01-05                 0.000000  249.537201      107.964317     0.000000
# ...                             ...         ...             ...          ...
# 2017-08-11                12.111111  468.857361       96.286926  2198.854492
# 2017-08-12                13.185185  354.342773       84.693817  2070.154785
# 2017-08-13                13.722222  379.801208       91.509422  2331.922363
# 2017-08-14                 9.259259  344.398285       86.062500  2134.399902
# 2017-08-15                10.962963  325.679810       85.954132  2316.832764
#
# family      SCHOOL AND OFFICE SUPPLIES    SEAFOOD
# date
# 2013-01-01                    0.000000   0.000000
# 2013-01-02                    0.000000  28.273148
# 2013-01-03                    0.000000  20.265018
# 2013-01-04                    0.000000  23.946686
# 2013-01-05                    0.000000  23.067352
# ...                                ...        ...
# 2017-08-11                   65.240738  23.566963
# 2017-08-12                   67.481483  19.037592
# 2017-08-13                   68.851852  20.704575
# 2017-08-14                   52.333332  17.975555
# 2017-08-15                   46.851852  17.966240
#
# [1684 rows x 33 columns]

# %% [markdown]
# #### 1. Correlation table from the complete dataset.

# %%
import pandas as pd
import numpy as np
 
 
corr = pivoted_table.corr()

corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/zj/cjnnn8695qx8mqcc36hww0y80000gp/T/ipykernel_31275/2738045748.py:7: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T
{
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_76c1c_row1_col9, #T_76c1c_row5_col31, #T_76c1c_row14_col31, #T_76c1c_row22_col16, #T_76c1c_row24_col2, #T_76c1c_row27_col11 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_76c1c_row1_col10, #T_76c1c_row4_col6, #T_76c1c_row6_col9, #T_76c1c_row13_col14, #T_76c1c_row23_col28, #T_76c1c_row24_col15 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_76c1c_row1_col11, #T_76c1c_row11_col25, #T_76c1c_row17_col20, #T_76c1c_row18_col22, #T_76c1c_row23_col17, #T_76c1c_row24_col31 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_76c1c_row1_col12, #T_76c1c_row9_col17, #T_76c1c_row18_col32, #T_76c1c_row31_col1 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_76c1c_row1_col13, #T_76c1c_row19_col17 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_76c1c_row1_col14, #T_76c1c_row13_col1, #T_76c1c_row14_col17, #T_76c1c_row23_col11 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_76c1c_row1_col15, #T_76c1c_row7_col30, #T_76c1c_row12_col1, #T_76c1c_row20_col23 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_

# %% [markdown]
# #### 2. Correlation table from '2015-06-15' onwards data.

# %%
trimed_train = train[train['date'] > '2015-06-15']
trimed_pivoted_table = trimed_train.pivot_table('sales', ['date'], 'family')
trimed_corr = trimed_pivoted_table.corr()

trimed_corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /var/folders/zj/cjnnn8695qx8mqcc36hww0y80000gp/T/ipykernel_31275/2102440515.py:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   trimed_corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_ed7d3_row0_col0, #T_ed7d3_row1_col1, #T_ed7d3_row2_col2, #T_ed7d3_row3_col3, #T_ed7d3_row4_col4, #T_ed7d3_row5_col5, #T_ed7d3_row6_col6, #T_ed7d3_row7_col7, #T_ed7d3_row8_col8, #T_ed7d3_row9_col9, #T_ed7d3_row10_col10, #T_ed7d3_row11_col11, #T_ed7d3_row12_col12, #T_ed7d3_row13_col13, #T_ed7d3_row14_col14, #T_ed7d3_row15_col15, #T_ed7d3_row16_col16, #T_ed7d3_row17_col17, #T_ed7d3_row18_col18, #T_ed7d3_row19_col19, #T_ed7d3_row20_col20, #T_ed7d3_row21_col21, #T_ed7d3_row22_col22, #T_ed7d3_row23_col23, #T_ed7d3_row24_col24, #T_ed7d3_row25_col25, #T_ed7d3_row26_col26, #T_ed7d3_row27_col27, #T_ed7d3_row28_col28, #T_ed7d3_row29_col29, #T_ed7d3_row30_col30, #T_ed7d3_row31_col31, #T_ed7d3_row32_col32 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ed7d3_row0_col1, #T_ed7d3_row6_col8, #T_ed7d3_row6_col25, #T_ed7d3_row9_col4, #T_ed7d3_row20_col28, #T_ed7d3_row21_col11, #T_ed7d3_row30_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_ed7d3_row0_col2, #T_ed7d3_row5_col32, #T_ed7d3_row26_col19, #T_ed7d3_row26_col25, #T_ed7d3_row27_col26, #T_ed7d3_row28_col29, #T_ed7d3_row29_col7 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_ed7d3_row0_col3, #T_ed7d3_row0_col25, #T_ed7d3_row9_col0, #T_ed7d3_row9_col12, #T_ed7d3_row27_col7 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_ed7d3_row0_col4, #T_ed7d3_row1_col14, #T_ed7d3_row11_col25, #T_ed7d3_row25_col22 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_ed7d3_row0_col5, #T_ed7d3_row0_col29, #T_ed7d3_row5_col10, #T_ed7d3_row5_col12, #T_ed7d3_row7_col19, #T_ed7d3_row8_col29, #T_ed7d3_row26_col5 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_ed7d3_row0_
;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col19, #T_44e7a_row0_col29, #T_44e7a_row1_col10, #T_44e7a_row9_col31, #T_44e7a_row16_col9, #T_44e7a_row17_col7 {
#   background-color: #97b8ff;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col20, #T_44e7a_row1_col5, #T_44e7a_row20_col12 {
#   background-color: #edd2c3;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col21, #T_44e7a_row5_col19, #T_44e7a_row13_col10, #T_44e7a_row19_col30, #T_44e7a_row25_col21, #T_44e7a_row30_col3, #T_44e7a_row32_col18 {
#   background-color: #bcd2f7;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col22, #T_44e7a_row14_col9, #T_44e7a_row14_col22, #T_44e7a_row15_col29, #T_44e7a_row20_col13, #T_44e7a_row24_col22, #T_44e7a_row29_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col23, #T_44e7a_row3_col2, #T_44e7a_row6_col29, #T_44e7a_row8_col30, #T_44e7a_row12_col30, #T_44e7a_row16_col32, #T_44e7a_row22_col19, #T_44e7a_row24_col16, #T_44e7a_row28_col2, #T_44e7a_row29_col3, #T_44e7a_row31_col17 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col24, #T_44e7a_row1_col13, #T_44e7a_row18_col0 {
#   background-color: #f4987a;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col26, #T_44e7a_row5_col3, #T_44e7a_row8_col26, #T_44e7a_row9_col17, #T_44e7a_row12_col11, #T_44e7a_row13_col21 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col27, #T_44e7a_row10_col2, #T_44e7a_row10_col27, #T_44e7a_row11_col0, #T_44e7a_row11_col8, #T_44e7a_row11_col14, #T_44e7a_row16_col13, #T_44e7a_row18_col19, #T_44e7a_row25_col0, #T_44e7a_row27_col28, #T_44e7a_row32_col8 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col28, #T_44e7a_row2_col10, #T_44e7a_row3_col0, #T_44e7a_row4_col26, #T_44e7a_row12_col2, #T_44e7a_row20_col30, #T_44e7a_row24_col31, #T_44e7a_row32_col26 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col30, #T_44e7a_row6_col28, #T_44e7a_row7_col25, #T_44e7a_row10_col30, #T_44e7a_row11_col18, #T_44e7a_row11_col30, #T_44e7a_row13_col17, #T_44e7a_row13_col19, #T_44e7a_row14_col19, #T_44e7a_row22_col20, #T_44e7a_row25_col7, #T_44e7a_row32_col14 {
#   background-color: #516ddb;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col31, #T_44e7a_row4_col23, #T_44e7a_row4_col31, #T_44e7a_row9_col4, #T_44e7a_row17_col25, #T_44e7a_row31_col2, #T_44e7a_row31_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
#   font-size: 0pt;
# }
# #T_44e7a_row0_col32, #T_44e7a_row3_col8, #T_44e7a_row9_col2, #T_44e7a_row11_col19, #T_44e7a_row22_col21, #T_44e7a_row22_col27, #T_44e7a_row22_col29, #T_44e7a_row25_col22, #T_44e7a_row26_col14, #T_44e7a_row28_col17 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row1_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row1_col2 {
#   background-color: #ee8669;
#   color: #f1f1f1;
#   font-size: 0pt;
# }
# #T_44e7a_row1_col3, #T_44e7a_row15_col11 {
#   background-color: #f39778;
#   col

# %% [markdown]
# ## Exploratory Data Analysis -- Food for Thought
#
# + While generally the product families are correlated with each other, there is significant difference in their
# characteristics.
# + Time will be a significant factor in our analysis -- there is an upward trend of overall sales.
# + There are anomalies that require further understanding of the dataset.
# + Some products have gross amount of missing data. We need to find an explanation for this or else a significant
# portion of the past data is not reliable. We may be forced to use only the most recent half of the dataset for
# full analysis.
# + How do we take advantage of, or deal with, the various kinds of correlation between different product families?
# Obviously they are related but they don't move in lock steps.

# %%
pivoted_table
# Out:
# family        date  AUTOMOTIVE  BABY CARE    BEAUTY    BEVERAGES     BOOKS  \
# 0       2013-01-01    0.000000   0.000000  0.037037    15.000000  0.000000
# 1       2013-01-02    4.722222   0.000000  3.833333  1335.037037  0.000000
# 2       2013-01-03    2.981481   0.000000  2.314815   964.907407  0.000000
# 3       2013-01-04    3.129630   0.000000  2.462963  1003.092593  0.000000
# 4       2013-01-05    6.333333   0.000000  3.537037  1441.074074  0.000000
# ...            ...         ...        ...       ...          ...       ...
# 1679    2017-08-11    8.166667   0.129630  6.500000  3502.055556  0.000000
# 1680    2017-08-12    7.462963   0.055556  6.833333  3376.259259  0.000000
# 1681    2017-08-13    8.907407   0.166667  8.018519  3747.296296  0.018519
# 1682    2017-08-14    5.407407   0.166667  6.240741  3237.629630  0.000000
# 1683    2017-08-15    6.240741   0.148148  6.277778  3162.462963  0.000000
#
# family  BREAD/BAKERY  CELEBRATION     CLEANING       DAIRY  ...  MAGAZINES  \
# 0           3.344241     0.000000     3.444444    2.648148  ...   0.000000
# 1         486.042944     0.000000  1382.018519  432.981481  ...   0.000000
# 2         341.786667     0.000000  1035.055556  333.351852  ...   0.000000
# 3         309.666093     0.000000   964.148148  336.074074  ...   0.000000
# 4         414.217798     0.000000  1298.666667  427.444444  ...   0.000000
# ...              ...          ...          ...         ...  ...        ...
# 1679      522.305296    16.111111  1031.148148  831.648148  ...   9.259259
# 1680      507.473111    15.722222  1072.870370  793.592593  ...   8.944444
# 1681      615.976981    10.074074  1143.648148  928.000000  ...   8.685185
# 1682      518.564019    11.000000  1019.111111  797.222222  ...   8.462963
# 1683      539.966574    11.055556  1082.851852  753.833333  ...   8.537037
#
# family       MEATS  PERSONAL CARE  PET SUPPLIES  PLAYERS AND ELECTRONICS  \
# 0         2.051870       0.462963      0.000000                 0.000000
# 1       386.508593     318.592593      0.000000                 0.000000
# 2       307.359224     232.740741      0.000000                 0.000000
# 3       400.480797     209.314815      0.000000                 0.000000
# 4       386.649834     311.462963      0.000000                 0.000000
# ...            ...            ...           ...                      ...
# 1679    498.964667     295.888889     10.870370                12.111111
# 1680    329.178706     294.500000      9.407407                13.185185
# 1681    345.055834     336.814815     10.018519                13.722222
# 1682    314.364556     279.203704      7.722222                 9.259259
# 1683    332.003166     273.833333      6.740741                10.962963
#
# family     POULTRY  PREPARED FOODS      PRODUCE  SCHOOL AND OFFICE SUPPLIES  \
# 0         0.789574        0.700870     0.000000                    0.000000
# 1       258.812684       98.853925     0.000000                    0.000000
# 2       197.673963       66.507185     0.000000                    0.000000
# 3       199.491019       82.832704     0.000000                    0.000000
# 4       249.537205      107.964315     0.000000                    0.000000
# ...            ...             ...          ...                         ...
# 1679    468.857370       96.286926  2198.854500                   65.240741
# 1680    354.342779       84.693815  2070.154646                   67.481481
# 1681    379.801204       91.509426  2331.922267                   68.851852
# 1682    344.398297       86.062500  2134.399926                   52.333333
# 1683    325.679815       85.954129  2316.832796                   46.851852
#
# family    SEAFOOD
# 0        0.000000
# 1       28.273148
# 2       20.265018
# 3       23.946685
# 4       23.067352
# ...           ...
# 1679    23.566963
# 1680    19.037593
# 1681    20.704574
# 1682    17.975556
# 1683    17.966241
#
# [1684 rows x 34 columns]

# %%
pivoted_table.reset_index(inplace=True, level = ['date'])

# %%
holidays.set_index('date').drop_duplicates(keep='first')
# Out:
#                   type    locale locale_name                    description  \
# date
# 2012-03-02     Holiday     Local       Manta             Fundacion de Manta
# 2012-04-01     Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 
# 2013-01-04  ...   0.000000  400.480797     209.314815      0.000000
# 2013-01-05  ...   0.000000  386.649834     311.462963      0.000000
# ...         ...        ...         ...            ...           ...
# 2017-08-11  ...   9.259259  498.964667     295.888889     10.870370
# 2017-08-12  ...   8.944444  329.178706     294.500000      9.407407
# 2017-08-13  ...   8.685185  345.055834     336.814815     10.018519
# 2017-08-14  ...   8.462963  314.364556     279.203704      7.722222
# 2017-08-15  ...   8.537037  332.003166     273.833333      6.740741
#
# family      PLAYERS AND ELECTRONICS     POULTRY  PREPARED FOODS      PRODUCE  \
# date
# 2013-01-01                 0.000000    0.789574        0.700870     0.000000
# 2013-01-02                 0.000000  258.812684       98.853925     0.000000
# 2013-01-03                 0.000000  197.673963       66.507185     0.000000
# 2013-01-04                 0.000000  199.491019       82.832704     0.000000
# 2013-01-05                 0.000000  249.537205      107.964315     0.000000
# ...                             ...         ...             ...          ...
# 2017-08-11                12.111111  468.857370       96.286926  2198.854500
# 2017-08-12                13.185185  354.342779       84.693815  2070.154646
# 2017-08-13                13.722222  379.801204       91.509426  2331.922267
# 2017-08-14                 9.259259  344.398297       86.062500  2134.399926
# 2017-08-15                10.962963  325.679815       85.954129  2316.832796
#
# family      SCHOOL AND OFFICE SUPPLIES    SEAFOOD
# date
# 2013-01-01                    0.000000   0.000000
# 2013-01-02                    0.000000  28.273148
# 2013-01-03                    0.000000  20.265018
# 2013-01-04                    0.000000  23.946685
# 2013-01-05                    0.000000  23.067352
# ...                                ...        ...
# 2017-08-11                   65.240741  23.566963
# 2017-08-12                   67.481481  19.037593
# 2017-08-13                   68.851852  20.704574
# 2017-08-14                   52.333333  17.975556
# 2017-08-15                   46.851852  17.966241
#
# [1684 rows x 33 columns]

# %%
train.loc[:,['sales','date']].groupby(['date']).sum()
# Out:
#                     sales
# date
# 2013-01-01    2511.618999
# 2013-01-02  496092.417944
# 2013-01-03  361461.231124
# 2013-01-04  354459.677093
# 2013-01-05  477350.121229
# ...                   ...
# 2017-08-11  826373.722022
# 2017-08-12  792630.535079
# 2017-08-13  865639.677471
# 2017-08-14  760922.406081
# 2017-08-15  762661.935939
#
# [1684 rows x 1 columns]

# %%
train
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3000883  3000883  2017-08-15          9                     POULTRY   438.133
# 3000884  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887  2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 3000883            0
# 3000884            1
# 3000885          148
# 3000886            8
# 3000887            0
#
# [3000888 rows x 6 columns]

# %%
df3 = holidays.merge(train, left_on='date', right_on='date')[['sales']]
df3
# Out:
#            sales
# 0          0.000
# 1          0.000
# 2          0.000
# 3          0.000
# 4          0.000
# ...          ...
# 502519   438.133
# 502520   154.553
# 502521  2419.729
# 502522   121.000
# 502523    16.000
#
# [502524 rows x 1 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(25,15))
train.plot.line(x='date', y='sales', ax = axes, rot=0)
holidays.plot.scatter(x='date',y=train[:sales], ax = axes, rot=0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zj/cjnnn8695qx8mqcc36hww0y80000gp/T/ipykernel_1536/3107596906.py in <module>
#       1 fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(25,15))
#       2 train.plot.line(x='date', y='sales', ax = axes, rot=0)
# ----> 3 holidays.plot.scatter(x='date',ax = axes, rot=0)
#       4 plt.show()
#
# TypeError: scatter() missing 1 required positional argument: 'y'
